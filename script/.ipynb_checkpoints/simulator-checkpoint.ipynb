# %% [markdown]
# # ***1.Import necessary libraries***

# %%
from preset_mdl import preset_mdl
from preset_pr import preset_pr
from signal_source import signal_source
from RISCA_core import RISCA_core
from analyser.analyser import AnalyserSar
import pandas as pd

# %% [markdown]
# # ***2.Initialize Objects and Pass Configuration Information***

# %%
# %matplotlib inline
# %pip install jinja2
mdl = preset_mdl()
pr = preset_pr()
pr['conf_name'] = input('配置文件名: sar/tisar/nssar1o1c/noisar1o1ccp/pipesar2s/...')
cfg_info = pd.DataFrame(pr["T_assembler"])
styled_df = cfg_info.style\
            .set_table_attributes('class="dataframe table table-striped"')\
            .set_properties(**{'text-align': 'center'})\
            .set_caption(f'Configuration Information for {pr["conf_name"]}')
styled_df
# Out:
# Loading file: ..\config\sar\timing_table.xlsx
# Loaded Excel configuration:
# <style type="text/css">
# #T_7439a_row0_col0, #T_7439a_row0_col1, #T_7439a_row0_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_7439a" class="dataframe table table-striped">
#   <caption>Configuration Information for sar</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7439a_level0_col0" class="col_heading level0 col0" >frame1</th>
#       <th id="T_7439a_level0_col1" class="col_heading level0 col1" >frame2</th>
#       <th id="T_7439a_level0_col2" class="col_heading level0 col2" >frame3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Item</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7439a_level0_row0" class="row_heading level0 row0" >CB1</th>
#       <td id="T_7439a_row0_col0" class="data row0 col0" >OUT RST SAM1</td>
#       <td id="T_7439a_row0_col1" class="data row0 col1" >MSB</td>
#       <td id="T_7439a_row0_col2" class="data row0 col2" >LSB</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # ***3.Input signal & Analysis conversion results***

# %%
# 定义输入信号峰值
v_in_peak = [0.85, 0]
# 调用 signal_source 函数
v_in_p, v_in_n = signal_source(pr, mdl, v_in_peak)

# Instantiate the device under test
da = RISCA_core(mdl, pr, v_in_p, v_in_n)
# Out:
# offset_nocal = 0.92 LSB

# %% [markdown]
# # ***4.Run Analysis***

# %%
test = AnalyserSar(da, pr)
test.no_calibration()
